# %%
# Connect the notebook to the Google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Go to the project directory - Add the name of your project folder after My Drive

# %cd gdrive/My Drive/FAKE_REVIEW/
# Out:
# /content/gdrive/My Drive/FAKE_REVIEW

# %%
cd /content/gdrive/MyDrive/FAKE_REVIEW
# Out:
# /content/gdrive/MyDrive/FAKE_REVIEW

# %%
import pandas as pd
import pickle
import numpy as np
pd.set_option('display.max_colwidth', None)

# %%
# Check the test files in the test data folder

# !ls Test_data
# Out:
# fake10.csv  fake4.csv  fake8.csv      genuine2.csv  genuine6.csv
# fake1.csv   fake5.csv  fake9.csv      genuine3.csv  genuine7.csv
# fake2.csv   fake6.csv  genuine10.csv  genuine4.csv  genuine8.csv
# fake3.csv   fake7.csv  genuine1.csv   genuine5.csv  genuine9.csv

# %%
# Read the test data from Test_data folder
# Try some fake reviews first


test = pd.read_csv('Test_data/fake3.csv')

# %%
# See the review

test.REVIEW_TEXT
# Out:
# 0    I was looking for an inexpensive desk calcolatur and here it is. It works and does everything I need. Only issue is that it tilts slightly to one side so when I hit any keys it rocks a little bit. Not a big deal.
# Name: REVIEW_TEXT, dtype: object

# %%
test = test.drop(['Unnamed: 0', 'REVIEW_TEXT'], axis = 1)

# %%
# Load the model

# Load the trained saved XGBoost model

XGB_model = pickle.load(open("XGB_model.pickle", "rb"))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [03:05:14] WARNING: /workspace/src/collective/../data/../common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Make prediction

y_pred = XGB_model.predict(test)

# %%
if y_pred == 0:
  print('This is a genuine review')
elif y_pred == 1:
  print('Fake review detected!')
# Out:
# Fake review detected!
